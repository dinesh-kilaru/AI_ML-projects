# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/WineQT.csv")

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %%
df.shape
# Out:
# (1143, 13)

# %%
df.sort_values("pH")
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 103             9.2              0.52         1.00             3.4      0.610
# 388            14.3              0.31         0.74             1.8      0.075
# 1047           10.0              0.69         0.11             1.4      0.084
# 310            12.6              0.31         0.72             2.2      0.072
# 714             8.0              0.18         0.37             0.9      0.049
# ...             ...               ...          ...             ...        ...
# 785             5.4              0.42         0.27             2.0      0.092
# 493             5.1              0.47         0.02             1.3      0.034
# 32              4.6              0.52         0.15             2.1      0.054
# 935             5.0              0.74         0.00             1.2      0.041
# 933             5.4              0.74         0.00             1.2      0.041
#
# ...

# %%
df["pH"]>2.70
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1138    True
# 1139    True
# 1140    True
# 1141    True
# 1142    True
# Name: pH, Length: 1143, dtype: bool

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1138    False
# 1139    False
# 1140    False
# 1141    False
# 1142    False
# Length: 1143, dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.sort_values("fixed acidity")
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 32             4.6             0.520         0.15             2.1      0.054
# 589            4.9             0.420         0.00             2.1      0.048
# 396            5.0             1.040         0.24             1.6      0.050
# 66             5.0             1.020         0.04             1.4      0.045
# 787            5.0             0.400         0.50             4.3      0.046
# ..             ...               ...          ...             ...        ...
# 171           15.0             0.210         0.44             2.2      0.075
# 397           15.5             0.645         0.49             4.2      0.095
# 399           15.6             0.645         0.49             4.2      0.095
# 311           15.6             0.685         0.76             3.7      0.100
# 462           15.9             0.360         0.65             7.5      0.096
#
# ...

# %%
print(df["fixed acidity"]<5.0)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1138    False
# 1139    False
# 1140    False
# 1141    False
# 1142    False
# Name: fixed acidity, Length: 1143, dtype: bool

# %%
df.groupby("quality")["fixed acidity"].mean()
# Out:
# quality
# 3    8.450000
# 4    7.809091
# 5    8.161077
# 6    8.317749
# 7    8.851049
# 8    8.806250
# Name: fixed acidity, dtype: float64

# %%
df.groupby("quality")["fixed acidity"].median()
# Out:
# quality
# 3    7.45
# 4    7.60
# 5    7.80
# 6    7.90
# 7    8.70
# 8    8.85
# Name: fixed acidity, dtype: float64

# %%
df.groupby("quality")["fixed acidity"].agg(["min","max"])
# Out:
#          min   max
# quality
# 3        6.7  11.6
# 4        4.6  12.5
# 5        5.0  15.9
# 6        5.0  14.3
# 7        4.9  15.6
# 8        5.0  12.6

# %%
df["fixed acidity"].mode()
# Out:
# 0    7.2
# Name: fixed acidity, dtype: float64

# %%
plt.boxplot(df["volatile acidity"])
plt.title("Boxplot of volatile acidity")
plt.xlabel("volatile acidity")
plt.ylabel("acidity")
plt.show()

# %%
outliers = df[(df['volatile acidity'] < lower_bound) | (df['volatile acidity'] > upper_bound)]
print( {len(outliers)})

display(outliers.head())
# Out:
# {14}
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 66            5.0              1.02         0.04             1.4      0.045
# 83            7.3              1.07         0.09             1.7      0.178
# 87            8.2              1.33         0.00             1.7      0.081
# 88            8.1              1.33         0.00             1.8      0.082
# 92            7.9              1.04         0.05             2.2      0.084
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 66                 41.0                  85.0   0.9938  3.75       0.48
# 83                 10.0                  89.0   0.9962  3.30       0.57
# 87                  3.0                  12.0   0.9964  3.53       0.49
# 88                  3.0                  12.0   0.9964  3.54       0.48
# 92                 13.0                  29.0   0.9959  3.22       0.55
#
#     alcohol  quality   Id
# 66     10.5        4   94
# ...

# %%
plt.boxplot(df_capped['volatile acidity'])
plt.title("Boxplot of volatile acidity (after capping outliers)")
plt.xlabel("volatile acidity")
plt.ylabel("acidity")
plt.show()

# %%
df["fixed acidity"].hist()
# Out:
# <Axes: >

# %%
df["free sulfur dioxide"].plot(kind="line")
# Out:
# <Axes: >

# %%
citric_acid_counts = df['citric acid'].value_counts()
plt.figure(figsize=(10, 8))
plt.pie(citric_acid_counts, labels=citric_acid_counts.index)
plt.axis('equal')
plt.show()

# %%
correlation_matrix = df.corr(numeric_only=True)
display(correlation_matrix)
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.250728     0.673157
# volatile acidity          -0.250728          1.000000    -0.544187
# citric acid                0.673157         -0.544187     1.000000
# residual sugar             0.171831         -0.005751     0.175815
# chlorides                  0.107889          0.056336     0.245312
# free sulfur dioxide       -0.164831         -0.001962    -0.057589
# total sulfur dioxide      -0.110628          0.077748     0.036871
# density                    0.681501          0.016512     0.375243
# pH                        -0.685163          0.221492    -0.546339
# sulphates                  0.174592         -0.276079     0.331232
# alcohol                   -0.075055         -0.203909     0.106250
# quality                    0.121970         -0.407394     0.240821
# Id                        -0.275826         -0.007892    -0.139011
#
# ...

# %% [markdown]
# Data Integrity: The dataset was found to be clean, with no missing values. Duplicate rows were successfully identified and removed, ensuring data uniqueness.
# Outlier Management: Outliers were present in 'volatile acidity' and effectively treated by capping them to the IQR bounds, which helped in normalizing its distribution without removing data points.
# Quality Insights: Higher wine quality appears to correlate with slightly higher 'fixed acidity' values. This suggests a potential relationship between these factors.
# Feature Interrelations: The correlation matrix revealed several relationships: 'fixed acidity' is positively correlated with 'citric acid' and 'density' but negatively with 'pH'. 'volatile acidity' has a negative correlation with 'citric acid' and 'quality'. Additionally, 'alcohol' shows a positive correlation with 'quality'. While many features are moderately correlated, no extremely high correlations (above 0.7 absolute value) were identified among distinct pairs, indicating a reasonable independence among features for further modeling.
